# %% [markdown]
# <a href="https://colab.research.google.com/github/kelly1325/Python/blob/main/KellyG_module5_finding_top_rated_movie_directors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Finding the Top Rated Movie Directors

# %% [markdown]
# Using the data on IMDB movies located at the following url, obtain the 20 highest rated movie directors based on their average movie IMDB ratings.
#
#  - Only consider directors with a minimum of 4 movies, otherwise you get misrepresentative data.
#  - Take movies of year >= 1960.
#  - Print the top 20 highest rated directors with their movies ordered desc on rating

# %%
import pandas as pd
dataUrl = 'https://raw.githubusercontent.com/sundeepblue/movie_rating_prediction/master/movie_metadata.csv'
data = pd.read_csv(dataUrl)

# %%
data
# Out:
#       color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0     Color      James Cameron  ...          1.78                 33000
# 1     Color     Gore Verbinski  ...          2.35                     0
# 2     Color         Sam Mendes  ...          2.35                 85000
# 3     Color  Christopher Nolan  ...          2.35                164000
# 4       NaN        Doug Walker  ...           NaN                     0
# ...     ...                ...  ...           ...                   ...
# 5038  Color        Scott Smith  ...           NaN                    84
# 5039  Color                NaN  ...         16.00                 32000
# 5040  Color   Benjamin Roberds  ...           NaN                    16
# 5041  Color        Daniel Hsia  ...          2.35                   660
# 5042  Color           Jon Gunn  ...          1.85                   456
#
# [5043 rows x 28 columns]

# %%
data = data.loc[data['title_year']>=1960]
data
# Out:
#       color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0     Color      James Cameron  ...          1.78                 33000
# 1     Color     Gore Verbinski  ...          2.35                     0
# 2     Color         Sam Mendes  ...          2.35                 85000
# 3     Color  Christopher Nolan  ...          2.35                164000
# 5     Color     Andrew Stanton  ...          2.35                 24000
# ...     ...                ...  ...           ...                   ...
# 5037  Color       Edward Burns  ...           NaN                   413
# 5038  Color        Scott Smith  ...           NaN                    84
# 5040  Color   Benjamin Roberds  ...           NaN                    16
# 5041  Color        Daniel Hsia  ...          2.35                   660
# 5042  Color           Jon Gunn  ...          1.85                   456
#
# [4861 rows x 28 columns]

# %%
director= data.director_name.value_counts()
director
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        17
#                     ..
# Allison Burnett      1
# Zoran Lisinac        1
# Rupert Sanders       1
# Tom McGrath          1
# Deon Taylor          1
# Name: director_name, Length: 2357, dtype: int64

# %%
director[director>=4]
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        17
#                     ..
# Hugh Wilson          4
# Jonathan Levine      4
# Joss Whedon          4
# Shane Meadows        4
# Anthony Russo        4
# Name: director_name, Length: 347, dtype: int64

# %%
selected = data.loc[data.director_name.isin(list(director[director>=4].keys()))]
selected.groupby('director_name')['imdb_score'].mean().sort_values(ascending=False).head(20)
# Out:
# director_name
# Sergio Leone             8.475000
# Christopher Nolan        8.425000
# Hayao Miyazaki           8.225000
# Quentin Tarantino        8.200000
# Stanley Kubrick          8.000000
# Frank Darabont           7.975000
# Joss Whedon              7.925000
# James Cameron            7.914286
# Alfonso Cuarón           7.800000
# Alejandro G. Iñárritu    7.783333
# David Fincher            7.750000
# Peter Weir               7.725000
# Peter Jackson            7.675000
# Martin Scorsese          7.660000
# Matthew Vaughn           7.650000
# David Lynch              7.640000
# Wes Anderson             7.628571
# Richard Attenborough     7.600000
# Edgar Wright             7.600000
# Paul Haggis              7.600000
# Name: imdb_score, dtype: float64
